# %% [markdown]
# # MECH 383 - Arduino Project
# <br>Names:
# <br> Titouan Dubray
# <br> William Jabbour
# <br> Antoine Petraki (260900783)
# <br>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# Plotting parameters
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif', size=14)
plt.rc('lines', linewidth=2)
plt.rc('axes', grid=True)
plt.rc('grid', linestyle='--')

# %%
# Import sensor data
data = np.genfromtxt('Sensor_Values.txt', delimiter=',')
print(data)
# Out:
# [857. 959. 960. ... 826. 837.   8.]

# %%
# Plot sensor data
time_step = 0.01 # 10ms
time = np.arange(0, len(data)*time_step, time_step)

plt.plot(time, data, label='Sensor 1')
plt.xlabel('Time (s)')
plt.ylabel('Sensor Value')
plt.title('Sensor Data')
# Out:
# Text(0.5, 1.0, 'Sensor Data')
